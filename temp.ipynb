# %%
import pandas as pd

# %%
df = pd.read_csv('messages.csv')

# %%
df = df.head(2000)

# %%
df = df.dropna()

# %%
df
# Out:
#                          FROM                       TO  \
# 0               Rashmi Dhakad  Hari Prasad Renganathan
# 1     Hari Prasad Renganathan            Rashmi Dhakad
# 2               Rashmi Dhakad  Hari Prasad Renganathan
# 3            Zeeshan Firdousi  Hari Prasad Renganathan
# 4            Zeeshan Firdousi  Hari Prasad Renganathan
# ...                       ...                      ...
# 1995  Hari Prasad Renganathan          Nicholas Kindig
# 1996  Hari Prasad Renganathan            Nilesh Bhoyar
# 1997  Hari Prasad Renganathan            Nilesh Bhoyar
# 1998            Nilesh Bhoyar  Hari Prasad Renganathan
# 1999  Hari Prasad Renganathan            Nilesh Bhoyar
#
#                                                 CONTENT
# 0                                      It's my pleasure
# 1     Hi Rashmi, thanks for your kind words. Sure th...
# 2     Hi Hari, loved the work you are doing with vid...
# 3                             Thanks for your response
# ...

# %%
df.to_csv('messages-sample.csv')
